# %%
import pandas as pd

# %%
fingerprint_address='../../intermediates/gc_with_morgan.bin'
spectra_address='../../intermediates/spectra_as_np_nist17gc.bin'

# %%
fingerprint_panda=pd.read_pickle(fingerprint_address)
spectra_panda=pd.read_pickle(spectra_address)

# %%
quantum_predicted_inchi_firstblock=['RGBVWCQARBEPPW',
'UXTUIDNFTDLRIX',
'UXTUIDNFTDLRIX',
'OECTYKWYRCHAKR',
'WMYNMYVRWWCRPS',
'JNYASWYZHOGSHZ',
'MDHZLHGRJCMNLA',
'YAMYUSZFVNTKPG',
'SDVVLIIVFBKBMG',
'ZOIRMVZWDRLJPI',
'CCQPAEQGAVNNIA',
'NMHNCGKWEZUMIX',
'MYHLVTYWMZRDMZ',
'GZOUQKLFUKOBFC',
'STCWNOWVXWSYAF',
'RINCXYDBBGOEEQ',
'JJTUDXZGHPGLLC',
'RUOJZAUFBMNUDX',
'GOOHAUXETOMSMM',
'AHHWIHXENZJRFG',
'RYHBNJHYFVUHQT',
'GFUHHAFPAPLHDR',
'DCZFGQYXRKMVFG',
'IAYPIBMASNFSPL',
'QDHIMWQUHRGIEV',
'BFPOIBUGVNVNKU',
'IZHVFAKMAKGJLM',
'NBBJYMSMWIIQGU',
'RZYIPLSVRHWROD',
'LVUQPCAQXKXOEE',
'GSDYNJRRFBBEJS',
'HHYYYQCRMPRQHX',
'KMTRUDSVKNLOMY',
'SYLAFCZSYRXBJF',
'AGGBUZDFXBQJIY',
'RGFKJRWDZOGFEG',
'MHZRCUVVJMWSMP',
'SRGUIJLJERBBCM',
'UBUUYJMRKQFFLA',
'XXTKORQHKOYXIH',
'IVJSVTUVNPAOTO',
'SRBFZHDQGSBBOR',
'ATFVTAOSZBVGHC',
'KEQUNHIAUQQPAC',
'QYSOFXYWZFPSCB',
'WQZGKKKJIJFFOK',
'BGJSXRVXTHVRSN',
'RDDFXEXZZMNBNN',
'GWGBQUOWRUBYTJ',
'RBGPCWFDIPYZNK',
'GOTCNQYWFYTGJN',
'FRZGGKAGDGVHBI',
'UEFLEQZTKKQMBA',
'YMGUBTXCNDTFJI',
'GXBYFVGCMPJVJX',
'FVCDMHWSPLRYAB',
'QAVYTTBRXJVSNJ',
'JZQHTTYHPIAPCZ',
'XSPNWUVAVYEPBO',
'SZERAFCDZCHRQS',
'DNHDRUMZDHWHKG',
'VSGACYFHLPVUQM',
'ICLNWIYCFZWTPE',
'AYKYXWQEBUNJCN',
'SLQIRJLLGUWLOC',
'ZPSJGADGUYYRKE',
'QKRUPRBAQFNCCY',
'GAJWLWOIFZSYOW',
'RRGABRVOWQSLPI',
'QBJOHGAEIAUULA',
'KDFBPHXESBPHTK',
'VTWTUVLDYHBQTC',
'LKTNAAYQZJAXCJ',
'SGKFFLPUDHYUQQ',
'ZJWYYAWAYYRFPV',
'AIQRJSXKXVZCJO',
'QPXKJZPVHDWMHT',
'RNKADCAFXYCJEN',
'LQPITCKFNIFQEH',
'MKWQOXREXMKNOA',
'OFNISBHGPNMTMS',
'GVJRTUUUJYMTNQ',
'XPXHSUOIQNJEQI',
'VDOKWPVSGXHSNP',
'PIXLZMHERIHLJL',
'SAVYPEZLECDCGS',
'VGTQPUNAYLVUSS',
'TYNJQOJWNMZQFZ',
'USEVBEOHTGJOOR',
'GELKGHVAFRCJNA',
'GXABMYNLRYTXGK',
'LIESJAYIOKBLIL',
'GEVZGXBMPXTKPK',
'BKSIPWIAFSUQKX',
'FZZIOLFULBXCKD',
'YZUOZLHQBCFIKB',
'LCYXQUJDODZYIJ',
'LGSHCFJZAMQQIF',
'QDIYYQQYVPMKJZ',
'RFBDBLSVNCYCGP',
'JRFXQKZEGILCCO',
'QGLBZNZGBLRJGS',
'SWSOFKZYSFBJSH',
'AMXASLDHSQRSDI',
'ZNAFWUJVHGNGIF',
'HXUXMDQJDDDOIJ',
'MBJJGJACXCAZKL',
'DTMPOWDLMOYPDD',
'UMXWFBSAWGHMMF',
'VGHBEMPMIVEGJP',
'PKAHQJNJPDVTDP',
'TWFKEGONKTUVSX',
'KIRRILZBWKPGLR',
'MMEAVAVRZYNYFB',
'BQPCLLPLCLJTSD',
'ARGCQEVBJHPOGB',
'JKTCBAGSMQIFNL',
'ULKFLOVGORAZDI',
'DOPFCVBSOPCWAQ',
'CXSOIAZZNZFSSR',
'QZXUQPKFNQQQAJ',
'QMFFTUAKXYCOKM',
'ATGXTJPMVRTSJY',
'KMTSPKJHYJTHDH',
'JJDXDJKPBZIXPI',
'XLOPRKKSAJMMEW',
'YEJRWHAVMIAJKC',
'VEZXCJBBBCKRPI',
'RKDVKSZUMVYZHH',
'RBACIKXCRWGCBB',
'FDSYWIWRUBJSDE',
'AEVNBIDPMSDSKG',
'CRDVOLPCGSIZKD',
'VZMRGSWFCBXBPW',
'GSCLMSFRWBPUSK',
'KPPWZEMUMPFHEX',
'WASQWSOJHCZDFK',
'SHQSVMDWKBRBGB',
'JZQBAGOECGRTSA',
'YBWJKTAELMMCHQ',
'OBQCRKRFVJMFQH',
'SJQITXILEOCXGI',
'RNFXAEBUWFIOQW',
'NUDBOGKLPOMBMP',
'XHYFCIYCSYEDCP',
'QPBYBLZYMNWGMO',
'OYJPJMVNLCUHNZ',
'WBHTXOSVODIGTN',
'PQXKWPLDPFFDJP',
'QQHZNUPEBVRUFO',
'YKNYRRVISWJDSR',
'OSYXXQUUGMLSGE',
'CMHPVTDHZRQCAR',
'DKNWSYNQZKUICI',
'SKSOGVQDJXWULT',
'CIJYMDAJQWMQSG',
'VLLNJDMHDJRNFK',
'ZQISSADDPTYZGO',
'KLMWXSLKNKFNDV',
'CERXFJHZAWSIBN',
'OFFQYGSGJUJTNN',
'MQEKHHGZLUHYRN',
'NJRFVURYVWPLKB',
'FOWDOWQYRZXQDP',
'FSVUOZUVEZBKGB',
'IQZMKGCMSXOILZ',
'IYKFYARMMIESOX',
'DOQQPEJQASLOBG',
'DKNWSYNQZKUICI',
'ORILYTVJVMAKLC',
'VWAIZPYLEYEEFK',
'CWNOIUTVJRWADX',
'MOLCWHCSXCKHAP',
'XPMPUGVKPUCKNN',
'RLXDPLARQIAXJE',
'QYZUXPQHBRUDQD',
'FJXQVRADKYKERU',
'NQPLKNMDHGQUDV',
'BURRFGDWEAFZRW',
'STDNHSQWRFEMLO',
'OTFHZSAGXXABSX',
'RXFCIXRFAJRBSG',
'SXJVFQLYZSNZBT',
'QMXSDTGNCZVWTB',
'XYCUJKFFVBCJEF',
'IBFRLHYBIOCBTE',
'QXOYPGTWWXJFDI',
'SEGJNMCIMOLEDM',
'AMJIVVJFADZSNZ',
'WBLXZSQLBOFHAB',
'PQYGBJHVVYREGU',
'ATHGHQPFGPMSJY',
'VILCJCGEZXAXTO',
'FYYPYNRGACGNNN',
'PIEFHHPASASGCR',
'DQUFJSBUTDTRNC',
'XPYXSZDENRDLKD',
'PLZZPPHAMDJOSR',
'MREJHSSUOXPZPS',
'YWWSWEIXJXYQJB',
'NJOLUQSSLMAZEB',
'WOVJAWMZNOWDII',
'AFXXJCGHWSTDDE',
'BTNXBLUGMAMSSH',
'DHLUQZDOGQUIOO',
'JOGSSTIPCUFRHC',
'IOQPZZOEVPZRBK',
'WSTNFGAKGUERTC',
'JQVDAXLFBXTEQA',
'KUOLUNCCCOMVGA',
'PWSKHLMYTZNYKO',
'AETGYOWKOXPRCB',
'OTBHHUPVCYLGQO',
'KXQQZMOVGZEPNH',
'GMYLJUMIAPOWOO',
'HSFHCHXOARWRSD',
'AIRUFVHYFDRGLU',
'SOGFATPCYLMCMQ',
'TXKWRPYUNDNNMI',
'LMDZBCPBFSXMTL',
'JRZJOMJEPLMPRA',
'YCBSHDKATAPNIA',
'YCBSHDKATAPNIA',
'KPADFPAILITQBG',
'IICQZTQZQSBHBY',
'KPADFPAILITQBG',
'KPADFPAILITQBG',
'YCBSHDKATAPNIA',
'IICQZTQZQSBHBY',
'IICQZTQZQSBHBY',
'IICQZTQZQSBHBY',
'YSIMAPNUZAVQER',
'AEUGPBYLZNGABC',
'AEUGPBYLZNGABC',
'FPGVMJDQNJEAJM',
'OSSQSXOTMIGBCF',
'RAYTXPDVKZFUEI',
'SRRDSRCWRHKEKU',
'LXKRETAGISZJAD',
'BBECVROIQDCRKP',
'NYLHDUHTALIPLY',
'CHGXUMHYPKPHMB',
'QPYQHAPIBCQICN',
'VJHGSLHHMIELQD',
'CLNYHERYALISIR',
'OXOUJUXDEZZIEF',
'MAMCJGWPGQJKLS',
'LSICDRUYCNGRIF',
'BKEVGGILGWUWSB',
'IFMLFZABZQNLON',
'MTHFROHDIWGWFD',
'CWPZHQHSRJKFMS',
'YFTHZRPMJXBUME',
'TVMXDCGIABBOFY',
'SBAJRGRUGUQKAF',
'WJYIASZWHGOTOU',
'XJINZNWPEQMMBV',
'ICVFPLUSMYSIFO',
'CWYZDPHNAGSFQB',
'GLFSDYCSLFSXBV',
'ODZZIKZQNODXFS',
'QOVUMEUQTMXUOS',
'OWKYZAGJTTTXOK',
'NAQMVNRVTILPCV',
'DFPGBRPWDZFIPP',
'ONCPEIKLFULSSA',
'CJKRXEBLWJVYJD',
'ALNDIBLAORBEAX',
'BOOQVRGRSDTZRZ',
'MBYLVOKEDDQJDY',
'ZSDXPCUFDUAKJY',
'FCKQTNVXHQEYLR',
'VSLJPTWFNWRVBG',
'VSLJPTWFNWRVBG',
'DQSIAGHCYOKRFM',
'BHZZIQKQPOHRIL',
'YICJUYKPMNNKIA',
'CGCWYQXCVFERRJ',
'UMOZTPPKYZWOTB',
'ZFQYTSCUGODUDB',
'GNERVRYWRNXNQS',
'GNERVRYWRNXNQS',
'OEDRQDWXEGWGBY',
'LADWJVRVWWFPKV',
'LTBOZHOOVZMBBF',
'XDBIRHORXBIDLP',
'URBIUAWKOUCECW',
'DNOJGXHXKATOKI',
'OAVPQXXPJZPXTA',
'CAPCBAYULRXQAN',
'UNEXJVCWJSHFNN',
'NRLOQPDAYBRDMK',
'YCTDZYMMFQCTEO',
'YCTDZYMMFQCTEO',
'KWKAKUADMBZCLK',
'IRUCBBFNLDIMIK',
'ILPBINAXDRFYPL',
'IRUCBBFNLDIMIK',
'UWHCKJMYHZGTIT',
'WFSMVVDJSNMRAR',
'YFNKIDBQEZZDLK',
'XRBWKWGATZNBFW',
'IXAWTPMDMPUGLV',
'OAYXUHPQHDHDDZ',
'RRQYJINTUHWNHW',
'JLGLQAWTXXGVEM',
'AVBRYQRTMPHARE',
'QDVIBEPABUQWMB',
'BELUYVNKSHWIJR',
'IIBZOHQVYOZRPJ',
'BDMCJNPMLSZYSL',
'YTTILRPAYBZIKQ',
'AYMDJPGTQFHDSA',
'FWMKRIYREKTLSC',
'YTNZKCVKQFVCJY',
'XSIAIXNDKLVFDS',
'UPGSWASWQBLSKZ',
'IWGVIHMNGVDKTH',
'GZHQUHIMIVEQFV',
'OEIJHBUUFURJLI',
'PAOHAQSLJSMLAT',
'OBXQRJAQMQQZMY',
'IIHAWQOFHTYWGM',
'SAMJGBVVQUEMGC',
'ZIBGPFATKBEMQZ',
'GYHFUZHODSMOHU',
'SCSDLMBSTOZBPZ',
'INRKVKPTZMIOTG',
'QJGFFKKLJRHCMV',
'QLVWOKQMDLQXNN',
'LNLKWQDISSHMLL',
'ADTIBIOIERBRIB',
'ZSCWUFCWRFKZGG',
'IBTAFYOTPNVGLR',
'CJKUBFJTBHACJH',
'WHFYLHIOEPSQJH',
'OOXWYYGXTJLWHA',
'LASLVGACQUUOEB',
'NOWKCMXCCJGMRR',
'LVZWSLJZHVFIQJ',
'DGZUEIPKRRSMGK',
'OGNAOIGAPPSUMG',
'SHDPRTQPPWIEJG',
'NJJDBBUBRAGNKG',
'MHLPKAGDPWUOOT',
'PNEUOFCODNXMRA',
'ONXARZMONCQRMU',
'XLJQPXVBQNJNLW',
'HTJDQJBWANPRPF',
'OZDGMOYKSFPLSE',
'VNWWNLCVXWGXIO',
'YIOCAJQMPUYWMT',
'FGRJGEWVJCCOJJ',
'WFNSDYPJGGQENT',
'SWSMPKJTKQYXPC',
'QWKHRBFLFYXNDY',
'PKCSMQZDZICOIA',
'GPBOEIMNJNTXIT',
'CGEYHDBRZXGTLN',
'KHCZAHBPHDGNJP',
'FYWVNXHGOQXBTP',
'QSUFBNDGMXCLRN',
'GPMHXZWOEIWUPW',
'IESGURQWOKTSMU',
'ZFIVKAOQEXOYFY',
'RZIHIJJOVJRDTA',
'WKXMKRGIACFCFA',
'YTFCTXSQQPWYFH',
'GJEZBVHHZQAEDB',
'QRDSDKAGXMWBID',
'HONIICLYMWZJFZ',
'AMSMVCOBCOZLEE',
'NODMEAHDWHZSNR',
'KPDOKSJMJMDRQA',
'NPTDXPDGUHAFKC',
'PMPVIKIVABFJJI',
'OMHSYLNUQGUJLG',
'KPCCPWBBOMBLEC',
'HSFWRNGVRCDJHI',
'KRRJYZCBLTXNCY',
'HHUSPFWAFUDXFF',
'ZVLXBROVKHBUMV',
'DNPSMEGHIHDFAJ',
'LDUKCCKFNKIVMS',
'AZGBUFPIKVKSCD',
'PSZPCAFRANQPLS',
'OTJYGFDMTQLPSU',
'VZNJDNKFUXILTJ',
'QYLMHRXTFJNXPK',
'OYLCLOGYABGECX',
'PZWQRDVVVKIYLX',
'SJYNFBVQFBRSIB',
'AUQDITHEDVOTCU',
'ZIFNDRXSSPCNID',
'AFICLWPORBGTPD',
'ADXLIAGMLNOWRF',
'HFCMQKFXCMZZMZ',
'WQQZKEFUOHKGII',
'UIVATUPCWVUVIM',
'KAESVJOAVNADME',
'YLQBMQCUIZJEEH',
'BXIIJPAVISPOGI',
'BMXGLUVWNGLWCQ',
'VHXMCTHNISBELQ',
'BSKNUNCXXRBFER',
'TYFPMPJIRDNPJL',
'KRPZXNZILJQDKG',
'MYKZRKOXOASWGJ',
'SZEDHOXKNCVHIL',
'SMJROXSMWHJZJX',
'ZSWFCLXCOIISFI',
'DLAUQDHZCKKXBK',
'OCLZLZYHIKOGPZ',
'GJTMXOICTLOFHO',
'UXMPPYGRAFYWRK',
'UBAWWGVGPSSQOC',
'NOOFIMYCZCAZSL',
'HEMCGZPSGYRIOL',
'MTFFBUSJVZMBOK',
'QOFLWDYWJZBWHM',
'UEKMEJJABUQZMZ',
'ZBLUGCVTVHUUCH',
'CTKINSOISVBQLD',
'FUYSJCQQUNMNIX',
'RAXXELZNTBOGNW',
'WTKZEGDFNFYCGP',
'ZCQWOFVYLHDMMC',
'CTAPFRYPJLPFDF',
'DLBWPRNUXWYLRN',
'WWYVZTLIFYLZFM',
'CSWPOLMVXVBCSV',
'IGSKHXTUVXSOMB',
'KZZKOVLJUKWSKX',
'KTHXBEHDVMTNOH',
'GUDMZGLFZNLYEY',
'HYSAJZJNEJKIMJ',
'RDPVUZMOVZHRHV',
'MIDDZYMFLRWZCN',
'XSKXEKKIOLQKBQ',
'RVDQZNUZKSPPND',
'HMDSXVUTCZSHDZ',
'SYQIWVMFOAHDMK',
'FKPDNKMXEGUTLZ',
'VGGSQFUCUMXWEO',
'AAVHHYWBSVSPPN',
'BLWIFXVIXXVYMI',
'JCHUCGKEGUAHEH',
'JKFAIQOWCVVSKC',
'QWENRTYMTSOGBR',
'NSPMIYGKQJPBQR',
'FKASFBLJDCHBNZ'
]

# %%
fingerprints_quantum_predicted=fingerprint_panda.loc[
    fingerprint_panda.inchikey_first_block.isin(quantum_predicted_inchi_firstblock)
]

# %%
spectra_quantum_predicted=spectra_panda.loc[
    spectra_panda.index.isin(fingerprints_quantum_predicted.index)
]

# %%
fingerprints_not_predicted=fingerprint_panda.loc[
    ~(fingerprint_panda.inchikey_first_block.isin(quantum_predicted_inchi_firstblock))
]

# %%
spectra_not_predicted=spectra_panda.loc[
    ~(spectra_panda.index.isin(fingerprints_quantum_predicted.index))
]

# %%
fingerprints_quantum_predicted.to_pickle('../../intermediates/split_by_shunyang_prediction/fingerprints_quantum_predicted.bin') 
fingerprints_not_predicted.to_pickle('../../intermediates/split_by_shunyang_prediction/fingerprints_not_predicted.bin') 

spectra_quantum_predicted.to_pickle('../../intermediates/split_by_shunyang_prediction/spectra_quantum_predicted.bin') 
spectra_not_predicted.to_pickle('../../intermediates/split_by_shunyang_prediction/spectra_not_predicted.bin')
